# %% [markdown]
# ## Графики функций нескольких переменных. Практика
# Отобразите графики следующих переменных при помощи sympy:
# 1. $f(x, y) = sin(\sqrt{x^2 + y^2})$
# 2. $f(x, y) = e^{-0.9x^2-0.45(x-y)^2}$ (задайте промежутки для x и y (𝑥,−3,3), (𝑦,−3,3))
# 3. $f(x, y) = xcos(y)$

# %% [markdown]
# ### Import

# %%
import sympy as sp
from sympy.plotting import plot3d
x, y = sp.symbols('x y')

# %% [markdown]
# ### Plot 1

# %%
f = sp.sin(sp.sqrt(x**2 + y**2))
plot3d(f)

# %% [markdown]
# ### Plot 2

# %%
f = sp.exp(-0.9*x**2-0.45*(x-y)**2)
plot3d(f, (x, -3, 3), (y, -3, 3))

# %% [markdown]
# ### Plot 3

# %%
f = x*sp.cos(y)
plot3d(f)
